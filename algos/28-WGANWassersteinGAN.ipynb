# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers

# 超参数设置
latent_dim = 100
n_critic = 5
epochs = 10000
batch_size = 64
clip_value = 0.01


# 生成器模型
def build_generator():
    model = tf.keras.Sequential()
    model.add(layers.Dense(256, input_dim=latent_dim))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(2, activation='tanh'))  # 生成2D数据
    return model


# 判别器模型
def build_critic():
    model = tf.keras.Sequential()
    model.add(layers.Dense(512, input_dim=2))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(256))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(1))  # 输出为一个标量
    return model


# 初始化生成器和判别器
generator = build_generator()
critic = build_critic()

# 编译判别器
critic.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.00005), loss='mean_squared_error')


# 生成数据
def generate_real_samples(n):
    x1 = np.random.uniform(-1.0, 1.0, n)
    x2 = np.random.uniform(-1.0, 1.0, n)
    return np.array(list(zip(x1, x2)))


def generate_latent_points(n):
    return np.random.normal(0, 1, (n, latent_dim))


def generate_fake_samples(n):
    z = generate_latent_points(n)
    return generator.predict(z)


# 训练WGAN
for epoch in range(epochs):
    # 训练判别器
    for _ in range(n_critic):
        # 生成真实样本和假样本
        X_real = generate_real_samples(batch_size)
        X_fake = generate_fake_samples(batch_size)

        # 更新判别器
        d_loss_real = critic.train_on_batch(X_real, np.ones((batch_size, 1)))
        d_loss_fake = critic.train_on_batch(X_fake, -np.ones((batch_size, 1)))

        # 进行权重裁剪
        for layer in critic.layers:
            weights = layer.get_weights()
            weights = [np.clip(w, -clip_value, clip_value) for w in weights]
            layer.set_weights(weights)

    # 训练生成器
    z = generate_latent_points(batch_size)
    g_loss = critic.train_on_batch(generator.predict(z), np.ones((batch_size, 1)))

    # 每1000轮打印一次损失
    if epoch % 1000 == 0:
        print(f'Epoch: {epoch}, D Loss Real: {d_loss_real}, D Loss Fake: {d_loss_fake}, G Loss: {g_loss}')


# 可视化生成的样本
def plot_generated_samples(generator, n=100):
    samples = generate_fake_samples(n)
    plt.scatter(samples[:, 0], samples[:, 1])
    plt.title("Generated Samples")
    plt.xlim(-2, 2)
    plt.ylim(-2, 2)
    plt.show()


plot_generated_samples(generator)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /Users/mikeshinoda/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /Users/mikeshinoda/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x28d803b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x28d803b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# Epoch: 0, D Loss Real: 0.9971429109573364, D Loss Fake: 0.9974877238273621, G Loss: 0.9976844787597656
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 69
#      66 X_fake = generate_fake_samples(batch_size)
#      68 # 更新判别器
# ---> 69 d_loss_real = critic.train_on_batch(X_real, np.ones((batch_size, 1)))
#      70 d_loss_fake = critic.train_on_batch(X_fake, -np.ones((batch_size, 1)))
#      72 # 进行权重裁剪
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:549, in TensorFlowTrainer.train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     546 def data():
#     547     yield (x, y, sample_weight)
# --> 549 logs = self.train_function(data())
#     550 logs = tree.map_structure(lambda x: np.array(x), logs)
#     551 if return_dict:
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:278, in _maybe_define_function(args, kwargs, tracing_options)
#     272 func_graph = func_graph_module.FuncGraph(tracing_options.name)
#     273 if (
#     274     tracing_options.input_signature is None
#     275     and tracing_options.reduce_retracing
#     276     and tracing_options.function_cache
#     277 ):
# --> 278   target_func_type = tracing_options.function_cache.generalize(
#     279       current_func_context, lookup_func_type
#     280   )
#     281 else:
#     282   target_func_type = lookup_func_type
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/core/function/polymorphism/function_cache.py:87, in FunctionCache.generalize(self, context, function_type)
#      85 """Try to generalize a FunctionType within a FunctionContext."""
#      86 if context in self._dispatch_dict:
# ---> 87   return self._dispatch_dict[context].try_generalizing_function_type(
#      88       function_type)
#      89 else:
#      90   return function_type
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/core/function/polymorphism/type_dispatch.py:128, in TypeDispatchTable.try_generalizing_function_type(self, target)
#     126 relaxed = target
#     127 for other in self._dispatch_table:
# --> 128   subtype = relaxed.most_specific_common_subtype([other])
#     129   if subtype is not None:
#     130     relaxed = subtype
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/core/function/polymorphism/function_type.py:310, in FunctionType.most_specific_common_subtype(self, others)
#     306 subtyped_parameters = []
#     308 for i, parameter in enumerate(self.parameters.values()):
#     309   # Functions are contravariant on their parameter types.
# --> 310   subtyped_parameter = parameter.most_specific_common_supertype(
#     311       [list(other.parameters.values())[i] for other in others])
#     312   if subtyped_parameter is None:
#     313     return None
#
# File ~/Library/Caches/pypoetry/virtualenvs/ai-algo-ozOH1ZQc-py3.12/lib/python3.12/site-packages/tensorflow/core/function/polymorphism/function_type.py:128, in Parameter.most_specific_common_supertype(self, others)
#     125 def most_specific_common_supertype(
#     126     self, others: Sequence["Parameter"]) -> Optional["Parameter"]:
#     127   """Returns a common supertype (if exists)."""
# --> 128   if not self.type_constraint or any(
#     129       not other.type_constraint for other in others):
#     130     raise TypeError(
#     131         "Can not determine relationship between partially specified types.")
#     133   for other in others:
#
# KeyboardInterrupt:
