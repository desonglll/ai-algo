# %%
import torch
import torch.nn as nn
import torch.optim as optim
import gym
import numpy as np
from collections import deque
import random


# 定义DQN模型
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 24)
        self.fc2 = nn.Linear(24, 24)
        self.fc3 = nn.Linear(24, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)


# 定义经验回放缓冲区
class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, transition):
        self.memory.append(transition)

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)


# 定义DQN智能体
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size

        self.memory = ReplayMemory(10000)
        self.gamma = 0.95  # 折扣因子
        self.epsilon = 1.0  # 探索率
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.batch_size = 64

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(state_size, action_size).to(self.device)
        self.target_net = DQN(state_size, action_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)
        self.update_target_every = 10  # 每10个回合更新一次目标网络

    def select_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.policy_net(state)
        return q_values.argmax().item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.push((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        minibatch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(self.device)

        # 当前Q值
        current_q = self.policy_net(states).gather(1, actions)
        # 下一个状态的最大Q值
        next_q = self.target_net(next_states).max(1)[0].unsqueeze(1)
        # 计算目标Q值
        target_q = rewards + (self.gamma * next_q * (1 - dones))

        # 计算损失
        loss = nn.MSELoss()(current_q, target_q)

        # 反向传播
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # 更新探索率
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())


# 训练函数
def train_dqn(episodes):
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    agent = DQNAgent(state_size, action_size)

    for e in range(1, episodes + 1):
        step_result = env.reset()
        if isinstance(step_result, tuple) or isinstance(step_result, list):
            if len(step_result) == 2:
                state, _ = step_result
            else:
                state = step_result[0]
        else:
            state = step_result  # 仅返回状态

        total_reward = 0
        done = False
        while not done:
            action = agent.select_action(state)
            step_result = env.step(action)
            if len(step_result) == 4:
                # 适用于旧版本 Gym
                next_state, reward, done, _ = step_result
            elif len(step_result) == 5:
                # 适用于新版本 Gym (如 Gymnasium)
                next_state, reward, terminated, truncated, _ = step_result
                done = terminated or truncated
            else:
                raise ValueError("Unexpected number of values returned by env.step()")

            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            agent.replay()

        if e % agent.update_target_every == 0:
            agent.update_target_network()
        print(f"回合 {e}/{episodes} - 奖励: {total_reward} - 探索率: {agent.epsilon:.4f}")
    env.close()


# 主程序
if __name__ == "__main__":
    train_dqn(episodes=500)
# Out:
# 回合 1/500 - 奖励: 32.0 - 探索率: 1.00
# 回合 2/500 - 奖励: 26.0 - 探索率: 1.00
# 回合 3/500 - 奖励: 26.0 - 探索率: 0.90
# 回合 4/500 - 奖励: 22.0 - 探索率: 0.81
# 回合 5/500 - 奖励: 13.0 - 探索率: 0.76
# 回合 6/500 - 奖励: 11.0 - 探索率: 0.71
# 回合 7/500 - 奖励: 19.0 - 探索率: 0.65
# 回合 8/500 - 奖励: 13.0 - 探索率: 0.61
# 回合 9/500 - 奖励: 13.0 - 探索率: 0.57
# 回合 10/500 - 奖励: 18.0 - 探索率: 0.52
# 回合 11/500 - 奖励: 11.0 - 探索率: 0.49
# 回合 12/500 - 奖励: 11.0 - 探索率: 0.47
# 回合 13/500 - 奖励: 18.0 - 探索率: 0.43
# 回合 14/500 - 奖励: 12.0 - 探索率: 0.40
# 回合 15/500 - 奖励: 13.0 - 探索率: 0.38
# 回合 16/500 - 奖励: 11.0 - 探索率: 0.36
# 回合 17/500 - 奖励: 13.0 - 探索率: 0.33
# 回合 18/500 - 奖励: 11.0 - 探索率: 0.32
# 回合 19/500 - 奖励: 10.0 - 探索率: 0.30
# 回合 20/500 - 奖励: 8.0 - 探索率: 0.29
# 回合 21/500 - 奖励: 13.0 - 探索率: 0.27
# 回合 22/500 - 奖励: 8.0 - 探索率: 0.26
# 回合 23/500 - 奖励: 10.0 - 探索率: 0.25
# 回合 24/500 - 奖励: 11.0 - 探索率: 0.23
# 回合 25/500 - 奖励: 12.0 - 探索率: 0.22
# 回合 26/500 - 奖励: 11.0 - 探索率: 0.21
# 回合 27/500 - 奖励: 10.0 - 探索率: 0.20
# 回合 28/500 - 奖励: 9.0 - 探索率: 0.19
# 回合 29/500 - 奖励: 10.0 - 探索率: 0.18
# 回合 30/500 - 奖励: 11.0 - 探索率: 0.17
# 回合 31/500 - 奖励: 14.0 - 探索率: 0.16
# 回合 32/500 - 奖励: 10.0 - 探索率: 0.15
# 回合 33/500 - 奖励: 11.0 - 探索率: 0.14
# 回合 34/500 - 奖励: 12.0 - 探索率: 0.13
# 回合 35/500 - 奖励: 9.0 - 探索率: 0.13
# 回合 36/500 - 奖励: 18.0 - 探索率: 0.12
# 回合 37/500 - 奖励: 12.0 - 探索率: 0.11
# 回合 38/500 - 奖励: 28.0 - 探索率: 0.10
# 回合 39/500 - 奖励: 8.0 - 探索率: 0.09
# 回合 40/500 - 奖励: 10.0 - 探索率: 0.09
# 回合 41/500 - 奖励: 17.0 - 探索率: 0.08
# 回合 42/500 - 奖励: 12.0 - 探索率: 0.08
# 回合 43/500 - 奖励: 16.0 - 探索率: 0.07
# 回合 44/500 - 奖励: 21.0 - 探索率: 0.06
# 回合 45/500 - 奖励: 20.0 - 探索率: 0.06
# 回合 46/500 - 奖励: 32.0 - 探索率: 0.05
# 回合 47/500 - 奖励: 16.0 - 探索率: 0.04
# 回合 48/500 - 奖励: 21.0 - 探索率: 0.04
# 回合 49/500 - 奖励: 11.0 - 探索率: 0.04
# 回合 50/500 - 奖励: 10.0 - 探索率: 0.04
# 回合 51/500 - 奖励: 58.0 - 探索率: 0.03
# 回合 52/500 - 奖励: 57.0 - 探索率: 0.02
# 回合 53/500 - 奖励: 66.0 - 探索率: 0.01
# 回合 54/500 - 奖励: 91.0 - 探索率: 0.01
# 回合 55/500 - 奖励: 95.0 - 探索率: 0.01
# 回合 56/500 - 奖励: 85.0 - 探索率: 0.01
# 回合 57/500 - 奖励: 92.0 - 探索率: 0.01
# 回合 58/500 - 奖励: 74.0 - 探索率: 0.01
# 回合 59/500 - 奖励: 98.0 - 探索率: 0.01
# 回合 60/500 - 奖励: 93.0 - 探索率: 0.01
# 回合 61/500 - 奖励: 139.0 - 探索率: 0.01
# 回合 62/500 - 奖励: 195.0 - 探索率: 0.01
# 回合 63/500 - 奖励: 134.0 - 探索率: 0.01
# 回合 64/500 - 奖励: 127.0 - 探索率: 0.01
# 回合 65/500 - 奖励: 142.0 - 探索率: 0.01
# 回合 66/500 - 奖励: 153.0 - 探索率: 0.01
# 回合 67/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 68/500 - 奖励: 139.0 - 探索率: 0.01
# 回合 69/500 - 奖励: 173.0 - 探索率: 0.01
# 回合 70/500 - 奖励: 161.0 - 探索率: 0.01
# 回合 71/500 - 奖励: 141.0 - 探索率: 0.01
# 回合 72/500 - 奖励: 163.0 - 探索率: 0.01
# 回合 73/500 - 奖励: 142.0 - 探索率: 0.01
# 回合 74/500 - 奖励: 131.0 - 探索率: 0.01
# 回合 75/500 - 奖励: 148.0 - 探索率: 0.01
# 回合 76/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 77/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 78/500 - 奖励: 132.0 - 探索率: 0.01
# 回合 79/500 - 奖励: 139.0 - 探索率: 0.01
# 回合 80/500 - 奖励: 135.0 - 探索率: 0.01
# 回合 81/500 - 奖励: 162.0 - 探索率: 0.01
# 回合 82/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 83/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 84/500 - 奖励: 165.0 - 探索率: 0.01
# 回合 85/500 - 奖励: 148.0 - 探索率: 0.01
# 回合 86/500 - 奖励: 167.0 - 探索率: 0.01
# 回合 87/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 88/500 - 奖励: 166.0 - 探索率: 0.01
# 回合 89/500 - 奖励: 141.0 - 探索率: 0.01
# 回合 90/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 91/500 - 奖励: 194.0 - 探索率: 0.01
# 回合 92/500 - 奖励: 174.0 - 探索率: 0.01
# 回合 93/500 - 奖励: 158.0 - 探索率: 0.01
# 回合 94/500 - 奖励: 161.0 - 探索率: 0.01
# 回合 95/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 96/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 97/500 - 奖励: 194.0 - 探索率: 0.01
# 回合 98/500 - 奖励: 182.0 - 探索率: 0.01
# 回合 99/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 100/500 - 奖励: 197.0 - 探索率: 0.01
# 回合 101/500 - 奖励: 168.0 - 探索率: 0.01
# 回合 102/500 - 奖励: 166.0 - 探索率: 0.01
# 回合 103/500 - 奖励: 193.0 - 探索率: 0.01
# 回合 104/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 105/500 - 奖励: 180.0 - 探索率: 0.01
# 回合 106/500 - 奖励: 186.0 - 探索率: 0.01
# 回合 107/500 - 奖励: 188.0 - 探索率: 0.01
# 回合 108/500 - 奖励: 169.0 - 探索率: 0.01
# 回合 109/500 - 奖励: 180.0 - 探索率: 0.01
# 回合 110/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 111/500 - 奖励: 364.0 - 探索率: 0.01
# 回合 112/500 - 奖励: 159.0 - 探索率: 0.01
# 回合 113/500 - 奖励: 223.0 - 探索率: 0.01
# 回合 114/500 - 奖励: 194.0 - 探索率: 0.01
# 回合 115/500 - 奖励: 360.0 - 探索率: 0.01
# 回合 116/500 - 奖励: 194.0 - 探索率: 0.01
# 回合 117/500 - 奖励: 232.0 - 探索率: 0.01
# 回合 118/500 - 奖励: 224.0 - 探索率: 0.01
# 回合 119/500 - 奖励: 405.0 - 探索率: 0.01
# 回合 120/500 - 奖励: 192.0 - 探索率: 0.01
# 回合 121/500 - 奖励: 283.0 - 探索率: 0.01
# 回合 122/500 - 奖励: 223.0 - 探索率: 0.01
# 回合 123/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 124/500 - 奖励: 219.0 - 探索率: 0.01
# 回合 125/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 126/500 - 奖励: 416.0 - 探索率: 0.01
# 回合 127/500 - 奖励: 284.0 - 探索率: 0.01
# 回合 128/500 - 奖励: 208.0 - 探索率: 0.01
# 回合 129/500 - 奖励: 191.0 - 探索率: 0.01
# 回合 130/500 - 奖励: 184.0 - 探索率: 0.01
# 回合 131/500 - 奖励: 192.0 - 探索率: 0.01
# 回合 132/500 - 奖励: 195.0 - 探索率: 0.01
# 回合 133/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 134/500 - 奖励: 179.0 - 探索率: 0.01
# 回合 135/500 - 奖励: 196.0 - 探索率: 0.01
# 回合 136/500 - 奖励: 209.0 - 探索率: 0.01
# 回合 137/500 - 奖励: 193.0 - 探索率: 0.01
# 回合 138/500 - 奖励: 174.0 - 探索率: 0.01
# 回合 139/500 - 奖励: 223.0 - 探索率: 0.01
# 回合 140/500 - 奖励: 182.0 - 探索率: 0.01
# 回合 141/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 142/500 - 奖励: 159.0 - 探索率: 0.01
# 回合 143/500 - 奖励: 196.0 - 探索率: 0.01
# 回合 144/500 - 奖励: 163.0 - 探索率: 0.01
# 回合 145/500 - 奖励: 201.0 - 探索率: 0.01
# 回合 146/500 - 奖励: 161.0 - 探索率: 0.01
# 回合 147/500 - 奖励: 193.0 - 探索率: 0.01
# 回合 148/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 149/500 - 奖励: 173.0 - 探索率: 0.01
# 回合 150/500 - 奖励: 190.0 - 探索率: 0.01
# 回合 151/500 - 奖励: 189.0 - 探索率: 0.01
# 回合 152/500 - 奖励: 196.0 - 探索率: 0.01
# 回合 153/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 154/500 - 奖励: 207.0 - 探索率: 0.01
# 回合 155/500 - 奖励: 153.0 - 探索率: 0.01
# 回合 156/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 157/500 - 奖励: 180.0 - 探索率: 0.01
# 回合 158/500 - 奖励: 147.0 - 探索率: 0.01
# 回合 159/500 - 奖励: 159.0 - 探索率: 0.01
# 回合 160/500 - 奖励: 161.0 - 探索率: 0.01
# 回合 161/500 - 奖励: 182.0 - 探索率: 0.01
# 回合 162/500 - 奖励: 182.0 - 探索率: 0.01
# 回合 163/500 - 奖励: 167.0 - 探索率: 0.01
# 回合 164/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 165/500 - 奖励: 174.0 - 探索率: 0.01
# 回合 166/500 - 奖励: 187.0 - 探索率: 0.01
# 回合 167/500 - 奖励: 152.0 - 探索率: 0.01
# 回合 168/500 - 奖励: 173.0 - 探索率: 0.01
# 回合 169/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 170/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 171/500 - 奖励: 171.0 - 探索率: 0.01
# 回合 172/500 - 奖励: 159.0 - 探索率: 0.01
# 回合 173/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 174/500 - 奖励: 148.0 - 探索率: 0.01
# 回合 175/500 - 奖励: 158.0 - 探索率: 0.01
# 回合 176/500 - 奖励: 161.0 - 探索率: 0.01
# 回合 177/500 - 奖励: 150.0 - 探索率: 0.01
# 回合 178/500 - 奖励: 148.0 - 探索率: 0.01
# 回合 179/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 180/500 - 奖励: 152.0 - 探索率: 0.01
# 回合 181/500 - 奖励: 130.0 - 探索率: 0.01
# 回合 182/500 - 奖励: 139.0 - 探索率: 0.01
# 回合 183/500 - 奖励: 126.0 - 探索率: 0.01
# 回合 184/500 - 奖励: 131.0 - 探索率: 0.01
# 回合 185/500 - 奖励: 142.0 - 探索率: 0.01
# 回合 186/500 - 奖励: 137.0 - 探索率: 0.01
# 回合 187/500 - 奖励: 124.0 - 探索率: 0.01
# 回合 188/500 - 奖励: 117.0 - 探索率: 0.01
# 回合 189/500 - 奖励: 147.0 - 探索率: 0.01
# 回合 190/500 - 奖励: 120.0 - 探索率: 0.01
# 回合 191/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 192/500 - 奖励: 77.0 - 探索率: 0.01
# 回合 193/500 - 奖励: 119.0 - 探索率: 0.01
# 回合 194/500 - 奖励: 140.0 - 探索率: 0.01
# 回合 195/500 - 奖励: 147.0 - 探索率: 0.01
# 回合 196/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 197/500 - 奖励: 171.0 - 探索率: 0.01
# 回合 198/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 199/500 - 奖励: 130.0 - 探索率: 0.01
# 回合 200/500 - 奖励: 168.0 - 探索率: 0.01
# 回合 201/500 - 奖励: 133.0 - 探索率: 0.01
# 回合 202/500 - 奖励: 138.0 - 探索率: 0.01
# 回合 203/500 - 奖励: 119.0 - 探索率: 0.01
# 回合 204/500 - 奖励: 131.0 - 探索率: 0.01
# 回合 205/500 - 奖励: 73.0 - 探索率: 0.01
# 回合 206/500 - 奖励: 139.0 - 探索率: 0.01
# 回合 207/500 - 奖励: 150.0 - 探索率: 0.01
# 回合 208/500 - 奖励: 51.0 - 探索率: 0.01
# 回合 209/500 - 奖励: 73.0 - 探索率: 0.01
# 回合 210/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 211/500 - 奖励: 63.0 - 探索率: 0.01
# 回合 212/500 - 奖励: 139.0 - 探索率: 0.01
# 回合 213/500 - 奖励: 104.0 - 探索率: 0.01
# 回合 214/500 - 奖励: 48.0 - 探索率: 0.01
# 回合 215/500 - 奖励: 132.0 - 探索率: 0.01
# 回合 216/500 - 奖励: 25.0 - 探索率: 0.01
# 回合 217/500 - 奖励: 96.0 - 探索率: 0.01
# 回合 218/500 - 奖励: 70.0 - 探索率: 0.01
# 回合 219/500 - 奖励: 123.0 - 探索率: 0.01
# 回合 220/500 - 奖励: 116.0 - 探索率: 0.01
# 回合 221/500 - 奖励: 44.0 - 探索率: 0.01
# 回合 222/500 - 奖励: 66.0 - 探索率: 0.01
# 回合 223/500 - 奖励: 115.0 - 探索率: 0.01
# 回合 224/500 - 奖励: 69.0 - 探索率: 0.01
# 回合 225/500 - 奖励: 274.0 - 探索率: 0.01
# 回合 226/500 - 奖励: 50.0 - 探索率: 0.01
# 回合 227/500 - 奖励: 102.0 - 探索率: 0.01
# 回合 228/500 - 奖励: 187.0 - 探索率: 0.01
# 回合 229/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 230/500 - 奖励: 209.0 - 探索率: 0.01
# 回合 231/500 - 奖励: 163.0 - 探索率: 0.01
# 回合 232/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 233/500 - 奖励: 166.0 - 探索率: 0.01
# 回合 234/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 235/500 - 奖励: 165.0 - 探索率: 0.01
# 回合 236/500 - 奖励: 196.0 - 探索率: 0.01
# 回合 237/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 238/500 - 奖励: 190.0 - 探索率: 0.01
# 回合 239/500 - 奖励: 184.0 - 探索率: 0.01
# 回合 240/500 - 奖励: 179.0 - 探索率: 0.01
# 回合 241/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 242/500 - 奖励: 149.0 - 探索率: 0.01
# 回合 243/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 244/500 - 奖励: 170.0 - 探索率: 0.01
# 回合 245/500 - 奖励: 175.0 - 探索率: 0.01
# 回合 246/500 - 奖励: 167.0 - 探索率: 0.01
# 回合 247/500 - 奖励: 168.0 - 探索率: 0.01
# 回合 248/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 249/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 250/500 - 奖励: 166.0 - 探索率: 0.01
# 回合 251/500 - 奖励: 158.0 - 探索率: 0.01
# 回合 252/500 - 奖励: 157.0 - 探索率: 0.01
# 回合 253/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 254/500 - 奖励: 146.0 - 探索率: 0.01
# 回合 255/500 - 奖励: 157.0 - 探索率: 0.01
# 回合 256/500 - 奖励: 150.0 - 探索率: 0.01
# 回合 257/500 - 奖励: 159.0 - 探索率: 0.01
# 回合 258/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 259/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 260/500 - 奖励: 149.0 - 探索率: 0.01
# 回合 261/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 262/500 - 奖励: 190.0 - 探索率: 0.01
# 回合 263/500 - 奖励: 169.0 - 探索率: 0.01
# 回合 264/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 265/500 - 奖励: 173.0 - 探索率: 0.01
# 回合 266/500 - 奖励: 167.0 - 探索率: 0.01
# 回合 267/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 268/500 - 奖励: 163.0 - 探索率: 0.01
# 回合 269/500 - 奖励: 157.0 - 探索率: 0.01
# 回合 270/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 271/500 - 奖励: 170.0 - 探索率: 0.01
# 回合 272/500 - 奖励: 199.0 - 探索率: 0.01
# 回合 273/500 - 奖励: 208.0 - 探索率: 0.01
# 回合 274/500 - 奖励: 209.0 - 探索率: 0.01
# 回合 275/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 276/500 - 奖励: 203.0 - 探索率: 0.01
# 回合 277/500 - 奖励: 191.0 - 探索率: 0.01
# 回合 278/500 - 奖励: 180.0 - 探索率: 0.01
# 回合 279/500 - 奖励: 215.0 - 探索率: 0.01
# 回合 280/500 - 奖励: 218.0 - 探索率: 0.01
# 回合 281/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 282/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 283/500 - 奖励: 176.0 - 探索率: 0.01
# 回合 284/500 - 奖励: 199.0 - 探索率: 0.01
# 回合 285/500 - 奖励: 95.0 - 探索率: 0.01
# 回合 286/500 - 奖励: 137.0 - 探索率: 0.01
# 回合 287/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 288/500 - 奖励: 162.0 - 探索率: 0.01
# 回合 289/500 - 奖励: 168.0 - 探索率: 0.01
# 回合 290/500 - 奖励: 158.0 - 探索率: 0.01
# 回合 291/500 - 奖励: 202.0 - 探索率: 0.01
# 回合 292/500 - 奖励: 225.0 - 探索率: 0.01
# 回合 293/500 - 奖励: 191.0 - 探索率: 0.01
# 回合 294/500 - 奖励: 212.0 - 探索率: 0.01
# 回合 295/500 - 奖励: 155.0 - 探索率: 0.01
# 回合 296/500 - 奖励: 159.0 - 探索率: 0.01
# 回合 297/500 - 奖励: 222.0 - 探索率: 0.01
# 回合 298/500 - 奖励: 264.0 - 探索率: 0.01
# 回合 299/500 - 奖励: 74.0 - 探索率: 0.01
# 回合 300/500 - 奖励: 167.0 - 探索率: 0.01
# 回合 301/500 - 奖励: 146.0 - 探索率: 0.01
# 回合 302/500 - 奖励: 130.0 - 探索率: 0.01
# 回合 303/500 - 奖励: 146.0 - 探索率: 0.01
# 回合 304/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 305/500 - 奖励: 131.0 - 探索率: 0.01
# 回合 306/500 - 奖励: 136.0 - 探索率: 0.01
# 回合 307/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 308/500 - 奖励: 32.0 - 探索率: 0.01
# 回合 309/500 - 奖励: 49.0 - 探索率: 0.01
# 回合 310/500 - 奖励: 72.0 - 探索率: 0.01
# 回合 311/500 - 奖励: 106.0 - 探索率: 0.01
# 回合 312/500 - 奖励: 91.0 - 探索率: 0.01
# 回合 313/500 - 奖励: 82.0 - 探索率: 0.01
# 回合 314/500 - 奖励: 126.0 - 探索率: 0.01
# 回合 315/500 - 奖励: 111.0 - 探索率: 0.01
# 回合 316/500 - 奖励: 189.0 - 探索率: 0.01
# 回合 317/500 - 奖励: 195.0 - 探索率: 0.01
# 回合 318/500 - 奖励: 131.0 - 探索率: 0.01
# 回合 319/500 - 奖励: 123.0 - 探索率: 0.01
# 回合 320/500 - 奖励: 315.0 - 探索率: 0.01
# 回合 321/500 - 奖励: 75.0 - 探索率: 0.01
# 回合 322/500 - 奖励: 135.0 - 探索率: 0.01
# 回合 323/500 - 奖励: 270.0 - 探索率: 0.01
# 回合 324/500 - 奖励: 194.0 - 探索率: 0.01
# 回合 325/500 - 奖励: 212.0 - 探索率: 0.01
# 回合 326/500 - 奖励: 140.0 - 探索率: 0.01
# 回合 327/500 - 奖励: 168.0 - 探索率: 0.01
# 回合 328/500 - 奖励: 208.0 - 探索率: 0.01
# 回合 329/500 - 奖励: 192.0 - 探索率: 0.01
# 回合 330/500 - 奖励: 152.0 - 探索率: 0.01
# 回合 331/500 - 奖励: 237.0 - 探索率: 0.01
# 回合 332/500 - 奖励: 175.0 - 探索率: 0.01
# 回合 333/500 - 奖励: 236.0 - 探索率: 0.01
# 回合 334/500 - 奖励: 203.0 - 探索率: 0.01
# 回合 335/500 - 奖励: 218.0 - 探索率: 0.01
# 回合 336/500 - 奖励: 219.0 - 探索率: 0.01
# 回合 337/500 - 奖励: 131.0 - 探索率: 0.01
# 回合 338/500 - 奖励: 291.0 - 探索率: 0.01
# 回合 339/500 - 奖励: 257.0 - 探索率: 0.01
# 回合 340/500 - 奖励: 251.0 - 探索率: 0.01
# 回合 341/500 - 奖励: 111.0 - 探索率: 0.01
# 回合 342/500 - 奖励: 323.0 - 探索率: 0.01
# 回合 343/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 344/500 - 奖励: 141.0 - 探索率: 0.01
# 回合 345/500 - 奖励: 229.0 - 探索率: 0.01
# 回合 346/500 - 奖励: 135.0 - 探索率: 0.01
# 回合 347/500 - 奖励: 114.0 - 探索率: 0.01
# 回合 348/500 - 奖励: 112.0 - 探索率: 0.01
# 回合 349/500 - 奖励: 221.0 - 探索率: 0.01
# 回合 350/500 - 奖励: 282.0 - 探索率: 0.01
# 回合 351/500 - 奖励: 228.0 - 探索率: 0.01
# 回合 352/500 - 奖励: 234.0 - 探索率: 0.01
# 回合 353/500 - 奖励: 126.0 - 探索率: 0.01
# 回合 354/500 - 奖励: 219.0 - 探索率: 0.01
# 回合 355/500 - 奖励: 110.0 - 探索率: 0.01
# 回合 356/500 - 奖励: 235.0 - 探索率: 0.01
# 回合 357/500 - 奖励: 212.0 - 探索率: 0.01
# 回合 358/500 - 奖励: 284.0 - 探索率: 0.01
# 回合 359/500 - 奖励: 279.0 - 探索率: 0.01
# 回合 360/500 - 奖励: 153.0 - 探索率: 0.01
# 回合 361/500 - 奖励: 113.0 - 探索率: 0.01
# 回合 362/500 - 奖励: 224.0 - 探索率: 0.01
# 回合 363/500 - 奖励: 129.0 - 探索率: 0.01
# 回合 364/500 - 奖励: 118.0 - 探索率: 0.01
# 回合 365/500 - 奖励: 118.0 - 探索率: 0.01
# 回合 366/500 - 奖励: 255.0 - 探索率: 0.01
# 回合 367/500 - 奖励: 112.0 - 探索率: 0.01
# 回合 368/500 - 奖励: 137.0 - 探索率: 0.01
# 回合 369/500 - 奖励: 99.0 - 探索率: 0.01
# 回合 370/500 - 奖励: 240.0 - 探索率: 0.01
# 回合 371/500 - 奖励: 337.0 - 探索率: 0.01
# 回合 372/500 - 奖励: 153.0 - 探索率: 0.01
# 回合 373/500 - 奖励: 301.0 - 探索率: 0.01
# 回合 374/500 - 奖励: 225.0 - 探索率: 0.01
# 回合 375/500 - 奖励: 179.0 - 探索率: 0.01
# 回合 376/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 377/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 378/500 - 奖励: 133.0 - 探索率: 0.01
# 回合 379/500 - 奖励: 298.0 - 探索率: 0.01
# 回合 380/500 - 奖励: 157.0 - 探索率: 0.01
# 回合 381/500 - 奖励: 208.0 - 探索率: 0.01
# 回合 382/500 - 奖励: 126.0 - 探索率: 0.01
# 回合 383/500 - 奖励: 218.0 - 探索率: 0.01
# 回合 384/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 385/500 - 奖励: 175.0 - 探索率: 0.01
# 回合 386/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 387/500 - 奖励: 223.0 - 探索率: 0.01
# 回合 388/500 - 奖励: 183.0 - 探索率: 0.01
# 回合 389/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 390/500 - 奖励: 188.0 - 探索率: 0.01
# 回合 391/500 - 奖励: 183.0 - 探索率: 0.01
# 回合 392/500 - 奖励: 163.0 - 探索率: 0.01
# 回合 393/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 394/500 - 奖励: 198.0 - 探索率: 0.01
# 回合 395/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 396/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 397/500 - 奖励: 186.0 - 探索率: 0.01
# 回合 398/500 - 奖励: 186.0 - 探索率: 0.01
# 回合 399/500 - 奖励: 204.0 - 探索率: 0.01
# 回合 400/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 401/500 - 奖励: 213.0 - 探索率: 0.01
# 回合 402/500 - 奖励: 225.0 - 探索率: 0.01
# 回合 403/500 - 奖励: 221.0 - 探索率: 0.01
# 回合 404/500 - 奖励: 204.0 - 探索率: 0.01
# 回合 405/500 - 奖励: 153.0 - 探索率: 0.01
# 回合 406/500 - 奖励: 212.0 - 探索率: 0.01
# 回合 407/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 408/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 409/500 - 奖励: 180.0 - 探索率: 0.01
# 回合 410/500 - 奖励: 212.0 - 探索率: 0.01
# 回合 411/500 - 奖励: 201.0 - 探索率: 0.01
# 回合 412/500 - 奖励: 148.0 - 探索率: 0.01
# 回合 413/500 - 奖励: 156.0 - 探索率: 0.01
# 回合 414/500 - 奖励: 217.0 - 探索率: 0.01
# 回合 415/500 - 奖励: 160.0 - 探索率: 0.01
# 回合 416/500 - 奖励: 194.0 - 探索率: 0.01
# 回合 417/500 - 奖励: 186.0 - 探索率: 0.01
# 回合 418/500 - 奖励: 193.0 - 探索率: 0.01
# 回合 419/500 - 奖励: 151.0 - 探索率: 0.01
# 回合 420/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 421/500 - 奖励: 174.0 - 探索率: 0.01
# 回合 422/500 - 奖励: 192.0 - 探索率: 0.01
# 回合 423/500 - 奖励: 361.0 - 探索率: 0.01
# 回合 424/500 - 奖励: 186.0 - 探索率: 0.01
# 回合 425/500 - 奖励: 166.0 - 探索率: 0.01
# 回合 426/500 - 奖励: 144.0 - 探索率: 0.01
# 回合 427/500 - 奖励: 166.0 - 探索率: 0.01
# 回合 428/500 - 奖励: 198.0 - 探索率: 0.01
# 回合 429/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 430/500 - 奖励: 183.0 - 探索率: 0.01
# 回合 431/500 - 奖励: 148.0 - 探索率: 0.01
# 回合 432/500 - 奖励: 239.0 - 探索率: 0.01
# 回合 433/500 - 奖励: 147.0 - 探索率: 0.01
# 回合 434/500 - 奖励: 147.0 - 探索率: 0.01
# 回合 435/500 - 奖励: 199.0 - 探索率: 0.01
# 回合 436/500 - 奖励: 138.0 - 探索率: 0.01
# 回合 437/500 - 奖励: 150.0 - 探索率: 0.01
# 回合 438/500 - 奖励: 163.0 - 探索率: 0.01
# 回合 439/500 - 奖励: 173.0 - 探索率: 0.01
# 回合 440/500 - 奖励: 195.0 - 探索率: 0.01
# 回合 441/500 - 奖励: 239.0 - 探索率: 0.01
# 回合 442/500 - 奖励: 136.0 - 探索率: 0.01
# 回合 443/500 - 奖励: 145.0 - 探索率: 0.01
# 回合 444/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 445/500 - 奖励: 161.0 - 探索率: 0.01
# 回合 446/500 - 奖励: 206.0 - 探索率: 0.01
# 回合 447/500 - 奖励: 154.0 - 探索率: 0.01
# 回合 448/500 - 奖励: 180.0 - 探索率: 0.01
# 回合 449/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 450/500 - 奖励: 177.0 - 探索率: 0.01
# 回合 451/500 - 奖励: 135.0 - 探索率: 0.01
# 回合 452/500 - 奖励: 130.0 - 探索率: 0.01
# 回合 453/500 - 奖励: 235.0 - 探索率: 0.01
# 回合 454/500 - 奖励: 120.0 - 探索率: 0.01
# 回合 455/500 - 奖励: 212.0 - 探索率: 0.01
# 回合 456/500 - 奖励: 129.0 - 探索率: 0.01
# 回合 457/500 - 奖励: 143.0 - 探索率: 0.01
# 回合 458/500 - 奖励: 136.0 - 探索率: 0.01
# 回合 459/500 - 奖励: 135.0 - 探索率: 0.01
# 回合 460/500 - 奖励: 134.0 - 探索率: 0.01
# 回合 461/500 - 奖励: 208.0 - 探索率: 0.01
# 回合 462/500 - 奖励: 195.0 - 探索率: 0.01
# 回合 463/500 - 奖励: 167.0 - 探索率: 0.01
# 回合 464/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 465/500 - 奖励: 190.0 - 探索率: 0.01
# 回合 466/500 - 奖励: 248.0 - 探索率: 0.01
# 回合 467/500 - 奖励: 242.0 - 探索率: 0.01
# 回合 468/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 469/500 - 奖励: 174.0 - 探索率: 0.01
# 回合 470/500 - 奖励: 170.0 - 探索率: 0.01
# 回合 471/500 - 奖励: 172.0 - 探索率: 0.01
# 回合 472/500 - 奖励: 184.0 - 探索率: 0.01
# 回合 473/500 - 奖励: 253.0 - 探索率: 0.01
# 回合 474/500 - 奖励: 192.0 - 探索率: 0.01
# 回合 475/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 476/500 - 奖励: 188.0 - 探索率: 0.01
# 回合 477/500 - 奖励: 185.0 - 探索率: 0.01
# 回合 478/500 - 奖励: 210.0 - 探索率: 0.01
# 回合 479/500 - 奖励: 184.0 - 探索率: 0.01
# 回合 480/500 - 奖励: 203.0 - 探索率: 0.01
# 回合 481/500 - 奖励: 195.0 - 探索率: 0.01
# 回合 482/500 - 奖励: 197.0 - 探索率: 0.01
# 回合 483/500 - 奖励: 164.0 - 探索率: 0.01
# 回合 484/500 - 奖励: 226.0 - 探索率: 0.01
# 回合 485/500 - 奖励: 199.0 - 探索率: 0.01
# 回合 486/500 - 奖励: 176.0 - 探索率: 0.01
# 回合 487/500 - 奖励: 196.0 - 探索率: 0.01
# 回合 488/500 - 奖励: 224.0 - 探索率: 0.01
# 回合 489/500 - 奖励: 187.0 - 探索率: 0.01
# 回合 490/500 - 奖励: 200.0 - 探索率: 0.01
# 回合 491/500 - 奖励: 187.0 - 探索率: 0.01
# 回合 492/500 - 奖励: 268.0 - 探索率: 0.01
# 回合 493/500 - 奖励: 178.0 - 探索率: 0.01
# 回合 494/500 - 奖励: 199.0 - 探索率: 0.01
# 回合 495/500 - 奖励: 181.0 - 探索率: 0.01
# 回合 496/500 - 奖励: 187.0 - 探索率: 0.01
# 回合 497/500 - 奖励: 216.0 - 探索率: 0.01
# 回合 498/500 - 奖励: 202.0 - 探索率: 0.01
# 回合 499/500 - 奖励: 190.0 - 探索率: 0.01
# 回合 500/500 - 奖励: 216.0 - 探索率: 0.01
