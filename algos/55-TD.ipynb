# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import random


class TDAgent:
    def __init__(self, env, alpha=0.1, gamma=0.99, epsilon_start=1.0, epsilon_min=0.1, epsilon_decay=0.995):
        self.env = env
        self.alpha = alpha  # 学习率
        self.gamma = gamma  # 折扣因子
        self.epsilon = epsilon_start  # 探索率初始值
        self.epsilon_min = epsilon_min  # 探索率最小值
        self.epsilon_decay = epsilon_decay  # 探索率衰减因子
        self.Q = np.zeros((env.observation_space.n, env.action_space.n))  # 初始化 Q 表

    def choose_action(self, state):
        """
        使用 ε-贪婪策略选择动作。
        """
        if random.uniform(0, 1) < self.epsilon:
            return self.env.action_space.sample()  # 探索
        else:
            return np.argmax(self.Q[state, :])  # 利用

    def learn(self, num_episodes=1000):
        """
        训练代理。
        """
        rewards = []
        for episode in range(num_episodes):
            # 处理不同版本 Gym 的 reset 返回值
            reset_return = self.env.reset(seed=None)
            if isinstance(reset_return, tuple):
                state, info = reset_return
            else:
                state = reset_return

            done = False
            total_reward = 0

            while not done:
                action = self.choose_action(state)
                step_return = self.env.step(action)
                if len(step_return) == 5:
                    next_state, reward, done, truncated, info = step_return
                elif len(step_return) == 4:
                    next_state, reward, done, info = step_return
                    truncated = False
                else:
                    raise ValueError("Unexpected number of return values from env.step()")

                done = done or truncated  # 处理 truncated 状态

                # TD(0) 更新规则
                best_next_action = np.argmax(self.Q[next_state, :])
                td_target = reward + self.gamma * self.Q[next_state, best_next_action] * (not done)
                td_error = td_target - self.Q[state, action]
                self.Q[state, action] += self.alpha * td_error

                state = next_state
                total_reward += reward

            rewards.append(total_reward)

            # 实施 ε 衰减
            if self.epsilon > self.epsilon_min:
                self.epsilon *= self.epsilon_decay
                self.epsilon = max(self.epsilon_min, self.epsilon)

            # 每100个回合输出一次信息
            if (episode + 1) % 100 == 0:
                avg_reward = np.mean(rewards[-100:])
                print(f"回合数: {episode + 1}, 最近100回合平均奖励: {avg_reward:.2f}, 当前ε: {self.epsilon:.4f}")

        return rewards

    def evaluate_policy(self, num_episodes=100, render=False):
        """
        使用学习到的 Q 表评估策略。
        """
        total_rewards = 0
        for episode in range(num_episodes):
            # 评估时设置固定种子以确保结果可重复性
            reset_return = self.env.reset(seed=42 + episode)
            if isinstance(reset_return, tuple):
                state, info = reset_return
            else:
                state = reset_return

            done = False
            episode_reward = 0
            while not done:
                action = np.argmax(self.Q[state, :])
                step_return = self.env.step(action)
                if len(step_return) == 5:
                    next_state, reward, done, truncated, info = step_return
                elif len(step_return) == 4:
                    next_state, reward, done, info = step_return
                    truncated = False
                else:
                    raise ValueError("Unexpected number of return values from env.step()")

                done = done or truncated
                episode_reward += reward
                state = next_state

                if render:
                    self.env.render()

            total_rewards += episode_reward
            print(f"评估回合 {episode + 1}, 奖励: {episode_reward}")

        average_reward = total_rewards / num_episodes
        print(f"评估平均奖励: {average_reward}")
        return average_reward


def plot_rewards(rewards, window=100):
    """
    绘制奖励曲线。
    """
    # 设置中文字体
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用黑体显示中文
    plt.rcParams['axes.unicode_minus'] = False  # 使负号正常显示

    plt.figure(figsize=(12, 8))
    plt.plot(rewards, label='奖励')
    # 计算滑动平均
    if len(rewards) >= window:
        cumsum = np.cumsum(np.insert(rewards, 0, 0))
        moving_avg = (cumsum[window:] - cumsum[:-window]) / window
        plt.plot(range(window, len(rewards) + 1), moving_avg, label=f'滑动平均（窗口={window}）')
    plt.xlabel('回合数')
    plt.ylabel('奖励')
    plt.title('TD(0) 在 FrozenLake-v1 上的训练奖励')
    plt.legend()
    plt.show()


def main():
    # 创建环境
    env = gym.make('FrozenLake-v1', is_slippery=False)  # 使用非滑动版，便于学习

    # 设置随机种子以确保结果可重复（仅在初始化时设置一次）
    reset_return = env.reset(seed=42)
    if isinstance(reset_return, tuple):
        state, info = reset_return
    else:
        state = reset_return

    np.random.seed(42)
    random.seed(42)

    # 初始化代理
    agent = TDAgent(env, alpha=0.1, gamma=0.99, epsilon_start=1.0, epsilon_min=0.1, epsilon_decay=0.995)

    # 训练代理
    num_episodes = 2000
    rewards = agent.learn(num_episodes=num_episodes)

    # 绘制奖励曲线
    plot_rewards(rewards)

    # 评估策略
    agent.evaluate_policy(num_episodes=100, render=False)

    # 关闭环境
    env.close()


if __name__ == "__main__":
    main()
# Out:
# 回合数: 100, 最近100回合平均奖励: 0.01, 当前ε: 0.6058
# 回合数: 200, 最近100回合平均奖励: 0.00, 当前ε: 0.3670
# 回合数: 300, 最近100回合平均奖励: 0.00, 当前ε: 0.2223
# 回合数: 400, 最近100回合平均奖励: 0.00, 当前ε: 0.1347
# 回合数: 500, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 600, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 700, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 800, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 900, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 1000, 最近100回合平均奖励: 0.01, 当前ε: 0.1000
# 回合数: 1100, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 1200, 最近100回合平均奖励: 0.00, 当前ε: 0.1000
# 回合数: 1300, 最近100回合平均奖励: 0.02, 当前ε: 0.1000
# 回合数: 1400, 最近100回合平均奖励: 0.89, 当前ε: 0.1000
# 回合数: 1500, 最近100回合平均奖励: 0.90, 当前ε: 0.1000
# 回合数: 1600, 最近100回合平均奖励: 0.88, 当前ε: 0.1000
# 回合数: 1700, 最近100回合平均奖励: 0.93, 当前ε: 0.1000
# 回合数: 1800, 最近100回合平均奖励: 0.91, 当前ε: 0.1000
# 回合数: 1900, 最近100回合平均奖励: 0.89, 当前ε: 0.1000
# 回合数: 2000, 最近100回合平均奖励: 0.94, 当前ε: 0.1000
# 评估回合 1, 奖励: 1.0
# 评估回合 2, 奖励: 1.0
# 评估回合 3, 奖励: 1.0
# 评估回合 4, 奖励: 1.0
# 评估回合 5, 奖励: 1.0
# 评估回合 6, 奖励: 1.0
# 评估回合 7, 奖励: 1.0
# 评估回合 8, 奖励: 1.0
# 评估回合 9, 奖励: 1.0
# 评估回合 10, 奖励: 1.0
# 评估回合 11, 奖励: 1.0
# 评估回合 12, 奖励: 1.0
# 评估回合 13, 奖励: 1.0
# 评估回合 14, 奖励: 1.0
# 评估回合 15, 奖励: 1.0
# 评估回合 16, 奖励: 1.0
# 评估回合 17, 奖励: 1.0
# 评估回合 18, 奖励: 1.0
# 评估回合 19, 奖励: 1.0
# 评估回合 20, 奖励: 1.0
# 评估回合 21, 奖励: 1.0
# 评估回合 22, 奖励: 1.0
# 评估回合 23, 奖励: 1.0
# 评估回合 24, 奖励: 1.0
# 评估回合 25, 奖励: 1.0
# 评估回合 26, 奖励: 1.0
# 评估回合 27, 奖励: 1.0
# 评估回合 28, 奖励: 1.0
# 评估回合 29, 奖励: 1.0
# 评估回合 30, 奖励: 1.0
# 评估回合 31, 奖励: 1.0
# 评估回合 32, 奖励: 1.0
# 评估回合 33, 奖励: 1.0
# 评估回合 34, 奖励: 1.0
# 评估回合 35, 奖励: 1.0
# 评估回合 36, 奖励: 1.0
# 评估回合 37, 奖励: 1.0
# 评估回合 38, 奖励: 1.0
# 评估回合 39, 奖励: 1.0
# 评估回合 40, 奖励: 1.0
# 评估回合 41, 奖励: 1.0
# 评估回合 42, 奖励: 1.0
# 评估回合 43, 奖励: 1.0
# 评估回合 44, 奖励: 1.0
# 评估回合 45, 奖励: 1.0
# 评估回合 46, 奖励: 1.0
# 评估回合 47, 奖励: 1.0
# 评估回合 48, 奖励: 1.0
# 评估回合 49, 奖励: 1.0
# 评估回合 50, 奖励: 1.0
# 评估回合 51, 奖励: 1.0
# 评估回合 52, 奖励: 1.0
# 评估回合 53, 奖励: 1.0
# 评估回合 54, 奖励: 1.0
# 评估回合 55, 奖励: 1.0
# 评估回合 56, 奖励: 1.0
# 评估回合 57, 奖励: 1.0
# 评估回合 58, 奖励: 1.0
# 评估回合 59, 奖励: 1.0
# 评估回合 60, 奖励: 1.0
# 评估回合 61, 奖励: 1.0
# 评估回合 62, 奖励: 1.0
# 评估回合 63, 奖励: 1.0
# 评估回合 64, 奖励: 1.0
# 评估回合 65, 奖励: 1.0
# 评估回合 66, 奖励: 1.0
# 评估回合 67, 奖励: 1.0
# 评估回合 68, 奖励: 1.0
# 评估回合 69, 奖励: 1.0
# 评估回合 70, 奖励: 1.0
# 评估回合 71, 奖励: 1.0
# 评估回合 72, 奖励: 1.0
# 评估回合 73, 奖励: 1.0
# 评估回合 74, 奖励: 1.0
# 评估回合 75, 奖励: 1.0
# 评估回合 76, 奖励: 1.0
# 评估回合 77, 奖励: 1.0
# 评估回合 78, 奖励: 1.0
# 评估回合 79, 奖励: 1.0
# 评估回合 80, 奖励: 1.0
# 评估回合 81, 奖励: 1.0
# 评估回合 82, 奖励: 1.0
# 评估回合 83, 奖励: 1.0
# 评估回合 84, 奖励: 1.0
# 评估回合 85, 奖励: 1.0
# 评估回合 86, 奖励: 1.0
# 评估回合 87, 奖励: 1.0
# 评估回合 88, 奖励: 1.0
# 评估回合 89, 奖励: 1.0
# 评估回合 90, 奖励: 1.0
# 评估回合 91, 奖励: 1.0
# 评估回合 92, 奖励: 1.0
# 评估回合 93, 奖励: 1.0
# 评估回合 94, 奖励: 1.0
# 评估回合 95, 奖励: 1.0
# 评估回合 96, 奖励: 1.0
# 评估回合 97, 奖励: 1.0
# 评估回合 98, 奖励: 1.0
# 评估回合 99, 奖励: 1.0
# 评估回合 100, 奖励: 1.0
# 评估平均奖励: 1.0
